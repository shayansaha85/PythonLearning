# %%
import pandas as pd

# %%
df = pd.read_csv('SampleSheet.csv') # jedike jupyter er file ta ase, oidikei SampleSheet.csv ta banailam

# %%
df
# Out:
#   firstname   lastname  age  company  salary
# 0    Tanmoy    Debnath   26   Whipro   35000
# 1    Subham    Debanth   27  Imfosys   37000
# 2   Pranjit  Chowdhury   25  Propero   27800
# 3  Supratim     Sarkar   25     JRBT   16700

# %%
df.to_csv('Output.csv', index=False) # df ta re csv te save koron

# %%
df_html = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)')

# %%
pip install lxml
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.9_2/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df_html
# Out:
# [                        Country / Area UN Continental Region[4]  \
#  0                                  NaN                      NaN
#  1                                India                     Asia
#  2                             China[a]                     Asia
#  3                        United States                 Americas
#  4                            Indonesia                     Asia
#  ..                                 ...                      ...
#  235                               Niue                  Oceania
#  236              Tokelau (New Zealand)                  Oceania
#  237                    Vatican City[y]                   Europe
#  238  Pitcairn Islands (United Kingdom)                  Oceania
#  239                              World                      NaN
#
#      UN Statistical Subregion[4]  Population (1 July 2022)  \
#  0                           NaN                       NaN
#  1                 Southern Asia              1.417173e+09
# ...

# %%
import pandas as pd

employeeData = pd.read_csv('SampleSheet.csv')

def incrementSalary(salary) :
    return round((salary + salary*0.3))

newSalary = list(employeeData['salary'].apply(incrementSalary))

newDataSet = {
    'firstname' : list(employeeData['firstname']),
    'lastname' :list(employeeData['lastname']),
    'age' :list(employeeData['age']),
    'company' :list(employeeData['company']),
    'salary' :list(employeeData['salary']),
    'notun_salary' : newSalary
}

new_employee_db = pd.DataFrame(newDataSet)



try: # jodi try er modhher code e error na thake, toile try execute hoibo
    new_employee_db.to_csv('NewEmployeeDB.csv', index=False)
    print("YOUR DATA IS SAVED SUCCESSFULLY")
    
except: # try e jekunu error thakle, except execute hoibo
    print("DATA SAVE ISSUE")
# Out:
# YOUR DATA IS SAVED SUCCESSFULLY

# %%
import pandas as pd

employeeData = pd.read_csv('SampleSheet.csv')

def incrementSalary(salary) :
    return round((salary + salary*0.3))

newSalary = list(employeeData['salary'].apply(incrementSalary))

employeeData.insert(5, 'new_salary', newSalary)

try: # jodi try er modhher code e error na thake, toile try execute hoibo
    employeeData.to_csv('NewEmployeeDB___2.csv', index=False)
    print("YOUR DATA IS SAVED SUCCESSFULLY")
    
except: # try e jekunu error thakle, except execute hoibo
    print("DATA SAVE ISSUE")
# Out:
# YOUR DATA IS SAVED SUCCESSFULLY

# %% [markdown]
# # COMPLICATED TOPIC : JOIN

# %%
import pandas as pd

# %%
df_1 = pd.DataFrame({
    'colA' : ['a0','a1','a2','a3'],
    'colB' : ['b0','b1','b2','b3'],
    'colC' : ['c0','c1','c2','c3'],
    'colD' : ['d0','d1','d2','d3']
})


df_2 = pd.DataFrame({
    'colA' : ['a4','a5','a6','a7'],
    'colB' : ['b4','b5','b6','b7'],
    'colC' : ['c4','c5','c6','c7'],
    'colD' : ['d4','d5','d6','d7']
})


df_3 = pd.DataFrame({
    'colA' : ['a8','a9','a10','a11'],
    'colB' : ['b8','b9','b10','b11'],
    'colC' : ['c8','c9','c10','c11'],
    'colD' : ['d8','d9','d10','d11']
})

# %%
df_1
# Out:
#   colA colB colC colD
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3

# %%
df_2
# Out:
#   colA colB colC colD
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7

# %%
df_3
# Out:
#   colA colB colC colD
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
# Concatenation

# %%
df_con_col = pd.concat([df_1, df_2, df_3])
df_con_col
# Out:
#   colA colB colC colD
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
df_con_row = pd.concat([df_1, df_2, df_3], axis=1)

# %%
df_con_row
# Out:
#   colA colB colC colD colA colB colC colD colA colB colC colD
# 0   a0   b0   c0   d0   a4   b4   c4   d4   a8   b8   c8   d8
# 1   a1   b1   c1   d1   a5   b5   c5   d5   a9   b9   c9   d9
# 2   a2   b2   c2   d2   a6   b6   c6   d6  a10  b10  c10  d10
# 3   a3   b3   c3   d3   a7   b7   c7   d7  a11  b11  c11  d11

# %%
left_df = pd.DataFrame({
    'pk' : ['k1','k2','k3','k4'],
    'colA' : ['a1','a2','a3','a4'],
    'colB' : ['b1','b2','b3','b4']
})

right_df = pd.DataFrame({
    'pk' : ['k1','k2','k3','k4'],
    'colC' : ['c1','c2','c3','c4'],
    'colD' : ['d1','d2','d3','d4']
})

# %%
left_df
# Out:
#    pk colA colB
# 0  k1   a1   b1
# 1  k2   a2   b2
# 2  k3   a3   b3
# 3  k4   a4   b4

# %%
right_df
# Out:
#    pk colC colD
# 0  k1   c1   d1
# 1  k2   c2   d2
# 2  k3   c3   d3
# 3  k4   c4   d4

# %%
pd.merge(left_df, right_df, how='inner', on='pk')
# Out:
#    pk colA colB colC colD
# 0  k1   a1   b1   c1   d1
# 1  k2   a2   b2   c2   d2
# 2  k3   a3   b3   c3   d3
# 3  k4   a4   b4   c4   d4

# %% [markdown]
# ## One level harder

# %%
l_df = pd.DataFrame({
    'pk1' : 'k0 k0 k1 k2'.split(),
    'pk2' : 'k0 k1 k0 k1'.split(),
    'colA' : 'a0 a1 a2 a3'.split(),
    'colB' : 'b0 b1 b2 b3'.split()
})

r_df = pd.DataFrame({
    'pk1' : 'k0 k1 k1 k2'.split(),
    'pk2' : 'k0 k0 k0 k0'.split(),
    'colC' : 'c0 c1 c2 c3'.split(),
    'colD' : 'd0 d1 d2 d3'.split()
})

# %%
l_df
# Out:
#   pk1 pk2 colA colB
# 0  k0  k0   a0   b0
# 1  k0  k1   a1   b1
# 2  k1  k0   a2   b2
# 3  k2  k1   a3   b3

# %%
r_df
# Out:
#   pk1 pk2 colC colD
# 0  k0  k0   c0   d0
# 1  k1  k0   c1   d1
# 2  k1  k0   c2   d2
# 3  k2  k0   c3   d3

# %%
pd.merge(l_df, r_df, on=['pk1', 'pk2'])
# Out:
#   pk1 pk2 colA colB colC colD
# 0  k0  k0   a0   b0   c0   d0
# 1  k1  k0   a2   b2   c1   d1
# 2  k1  k0   a2   b2   c2   d2

# %%
pd.merge(l_df, r_df, how='outer', on=['pk1', 'pk2'])
# Out:
#   pk1 pk2 colA colB colC colD
# 0  k0  k0   a0   b0   c0   d0
# 1  k0  k1   a1   b1  NaN  NaN
# 2  k1  k0   a2   b2   c1   d1
# 3  k1  k0   a2   b2   c2   d2
# 4  k2  k1   a3   b3  NaN  NaN
# 5  k2  k0  NaN  NaN   c3   d3

# %%
pd.merge(l_df, r_df, how='left', on=['pk1', 'pk2'])
# Out:
#   pk1 pk2 colA colB colC colD
# 0  k0  k0   a0   b0   c0   d0
# 1  k0  k1   a1   b1  NaN  NaN
# 2  k1  k0   a2   b2   c1   d1
# 3  k1  k0   a2   b2   c2   d2
# 4  k2  k1   a3   b3  NaN  NaN

# %%
pd.merge(l_df, r_df, how='right', on=['pk1', 'pk2'])
# Out:
#   pk1 pk2 colA colB colC colD
# 0  k0  k0   a0   b0   c0   d0
# 1  k1  k0   a2   b2   c1   d1
# 2  k1  k0   a2   b2   c2   d2
# 3  k2  k0  NaN  NaN   c3   d3

# %%
l_df = pd.DataFrame({
    'colA' : 'a0 a1 a2'.split(),
    'colB' : 'b0 b1 b2'.split()},
    index='k1 k2 k3'.split())

r_df = pd.DataFrame({
    'colC' : 'c0 c1 c2'.split(),
    'colD' : 'd0 d1 d2'.split()},
    index='k2 k3 k4'.split()
)

# %%
l_df
# Out:
#    colA colB
# k1   a0   b0
# k2   a1   b1
# k3   a2   b2

# %%
r_df
# Out:
#    colC colD
# k2   c0   d0
# k3   c1   d1
# k4   c2   d2

# %%
l_df.join(r_df)
# Out:
#    colA colB colC colD
# k1   a0   b0  NaN  NaN
# k2   a1   b1   c0   d0
# k3   a2   b2   c1   d1

# %%
l_df.join(r_df, how='outer')
# Out:
#    colA colB colC colD
# k1   a0   b0  NaN  NaN
# k2   a1   b1   c0   d0
# k3   a2   b2   c1   d1
# k4  NaN  NaN   c2   d2
